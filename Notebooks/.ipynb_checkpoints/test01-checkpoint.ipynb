# %%
import nbaShotCharts as nba
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-418bc63cef3f> in <module>()
# ----> 1 import nbaShotCharts as nba
#
# ImportError: No module named 'nbaShotCharts'

# %%
# get stephen curry's player id from
